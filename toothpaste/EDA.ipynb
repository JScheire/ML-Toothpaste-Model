# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 8]

# %%
data = pd.read_csv('data.csv')
print(data.shape)
data.head(3)
# Out:
# (14847, 7)
#    Unnamed: 0  country  company  total_pack_size_ml_g  unit_pack_size_ml_g  \
# 0           0  Vietnam  Brand 0                 130.0                130.0
# 1           1   Brazil  Brand 1                  90.0                 90.0
# 2           2  Vietnam  Brand 2                 120.0                120.0
#
#    price_per_100g_ml_dollars  \
# 0                       0.32
# 1                       1.22
# 2                       1.26
#
#                                          ingredients
# 0  CI 77220, Aqua, Sorbitol, Hydrated Silica (Hyd...
# 1  active ingredient: sodium monofluorophosphate ...
# 2  Sodium Fluoride CI 47005, Blue 1, flavor, Came...

# %%
print('%s unique countries' % len(data['country'].unique()))
print('%s unique brands' % len(data['company'].unique()))
# Out:
# 86 unique countries
# 1916 unique brands

# %%
data['price_per_100g_ml_dollars'].describe()
# Out:
# count    14847.000000
# mean         4.766271
# std          5.779356
# min          0.010000
# 25%          1.760000
# 50%          3.440000
# 75%          5.970000
# max        252.000000
# Name: price_per_100g_ml_dollars, dtype: float64

# %%
data['price_per_100g_ml_dollars'].clip(upper=30).plot(kind='hist', bins=30)

# %%
data['unit_pack_size_ml_g'].describe()
# Out:
# count    14847.000000
# mean        94.914851
# std         49.477564
# min          0.300000
# 25%         75.000000
# 50%         75.000000
# 75%        110.000000
# max       2218.010000
# Name: unit_pack_size_ml_g, dtype: float64

# %%
data['unit_pack_size_ml_g'].clip(upper=300).plot(kind='hist', bins=15)

# %%
data['total_pack_size_ml_g'].describe()
# Out:
# count    14834.000000
# mean       107.504447
# std        133.981818
# min          4.000000
# 25%         75.000000
# 50%         80.000000
# 75%        120.000000
# max      12825.000000
# Name: total_pack_size_ml_g, dtype: float64

# %%
data['total_pack_size_ml_g'].clip(upper=500).plot(kind='hist', bins=20, xlim=(0,500))

# %%
data['country'].value_counts().head(20).plot(kind='bar', title='Top 20 Countries')

# %%
data['company'].value_counts().head(20).plot(kind='bar', title='Top 20 Brands')

# %%
data.plot.scatter('total_pack_size_ml_g', 'price_per_100g_ml_dollars', xlim=(0,2000), ylim=(0,100))

# %%
data['company'].describe()
# Out:
# count       14847
# unique       1916
# top       Brand 0
# freq         2733
# Name: company, dtype: object
